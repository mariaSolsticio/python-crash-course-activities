# %%
# Creating the dog class

class Dog():
    """A simple attempt to model a dog."""
    
    def __init__(self, name, age):
        """Initialize name and age attributes."""
        self.name = name
        self.age = age
        
    def sit(self):
        """Simulate a dog sitting in response to a command."""
        print(self.name.title() + " is now sitting.")
        
    def roll_over(self):
        """Simulate rolling over in response to a command.""" 
        print(self.name.title() + " rolled over!")
        
# Creating the instance of the dog class
my_dog1 = Dog('Amelia', 4)
my_dog2 = Dog('Olivia', 3)

print("\nMy dog's name is " + my_dog1.name.title() + ".")
print("My dog is " + str(my_dog1.age) + " years old.")
print("\nMy dog's name is " + my_dog2.name.title() + ".")
print("My dog is " + str(my_dog2.age) + " years old.")

# Using the class methods
my_dog1.sit()
my_dog1.roll_over()
my_dog2.sit()
my_dog2.roll_over()

# %%
# Ex. 9-1 Restaurant
class Restaurant():
    
    def __init__(self, restaurant_name, cuisine_type):
        self.name = restaurant_name
        self.type = cuisine_type
        
    def describe_restaurant(self):
        print("\nThe restaurant is named " + self.name.title() + ",")
        print("and it specializes in " + self.type.title() + " cuisine.")
    
    def open_restaurant(self):
        print("\nThe restaurant is now open!")


restaurant1 = Restaurant("Taller Vegano", "Vegana")
print("Restaurant: " + restaurant1.name.title())
print("Type: " + restaurant1.type.title())
restaurant1.describe_restaurant()
restaurant1.open_restaurant()

restaurant2 = Restaurant("Árbol de la Vida", "Vegetariano")
print("Restaurant: " + restaurant2.name.title())
print("Type: " + restaurant2.type.title())
restaurant2.describe_restaurant()
restaurant2.open_restaurant()

restaurant3 = Restaurant("Vegannatta", "Vegana")
print("Restaurant: " + restaurant3.name.title())
print("Type: " + restaurant3.type.title())
restaurant3.describe_restaurant()
restaurant3.open_restaurant()

# %%
# Ex. 9-3 Users
class User():
    
    def __init__(self, first_name, last_name, age, role):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.role = role
        
    def describe_user(self):
        print(self)
    
    def greet_user(self):
        print("Hola " + self.first_name.title())

user1 = User("marcos", "morales", 33, "chef")
user2 = User("sol", "giron", 34, "creator")

user1.describe_user()
user2.describe_user()

# %%
# Create a Car class
class Car():
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()
    
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")
        
    def update_odometer(self, mileage):
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("The odometer cannot go backwards.")

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()

# Modifying an attribute's value directly
my_new_car.odometer_reading = 23
my_new_car.read_odometer()

# Modifying an attribute's value through a method
my_new_car.update_odometer(35)
my_new_car.read_odometer()

# %%
# Ex 9-4 Number served

# Ex. 9-1 Restaurant
class Restaurant():
    
    def __init__(self, restaurant_name, cuisine_type):
        self.name = restaurant_name
        self.type = cuisine_type
        self.number_served = 0
        
    def describe_restaurant(self):
        print("\nThe restaurant is named " + self.name.title() + ",")
        print("and it specializes in " + self.type.title() + " cuisine.")
    
    def open_restaurant(self):
        print("\nThe restaurant is now open!")
        
    def set_number_served(self, served):
        self.number_served = served
        
    def increment_number_served(self, daily_served):
        self.number_served += daily_served


restaurant = Restaurant("Taller Vegano", "Vegana")
print("This restaurant has served: " + str(restaurant.number_served) + " persons.")

# Changing the number of users served.
restaurant.number_served = 100
print("This restaurant has served: " + str(restaurant.number_served) + " persons.")

# Changing the number of users served through a method.
restaurant.set_number_served(120)
print("This restaurant has served: " + str(restaurant.number_served) + " persons.")

# Adding something to the attribute.
restaurant.increment_number_served(15)
print("This restaurant has served: " + str(restaurant.number_served) + " persons.")

# %%
# Ex. 9-5 Login attempts: 

class User():
    
    def __init__(self, first_name, last_name, age, role):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.role = role
        self.login_attempts = 0
        
    def describe_user(self):
        print(self)
    
    def greet_user(self):
        print("Hola " + self.first_name.title())
        
    def increment_login_attempts(self):
        self.login_attempts += 1
    
    def reset_login_attempts(self):
        self.login_attempts = 0

user = User("marcos", "morales", 33, "chef")
user.increment_login_attempts()
user.increment_login_attempts()

print(user.login_attempts)

user.reset_login_attempts()

print(user.login_attempts)

# %%
# INHERITANCE
class Car():
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()
    
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")
        
    def update_odometer(self, mileage):
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("The odometer cannot go backwards.")

# This one is the child class
class ElectricCar(Car):
    
    def __init__(self, make, model, year):
        # First initialize attributes of the parent class.
        super().__init__(make, model, year)
        # Now initialize attributes specific of an electric car.
        self.battery_size = 70
    
    def describe_battery(self):
        print("This car has a " + str(self.battery_size) + "-kWh battery.")

my_tesla = ElectricCar("tesla", "model s", 2016)
print(my_tesla.get_descriptive_name())
my_tesla.describe_battery()

# %%
# Instances as attributes

# INHERITANCE
class Car():
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()
    
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")
        
    def update_odometer(self, mileage):
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("The odometer cannot go backwards.")

# New class to hold the battery related attributes
# This will be passed as an attribute to the ElectricCar class later on

class Battery():
    
    def __init__(self, battery_size=70):
        self.battery_size = battery_size
    
    def describe_battery(self):
           print("This car has a " + str(self.battery_size) + "-kWh battery.")
            
    def get_range(self):
        if self.battery_size == 70:
            range = 240
        elif self.battery_size == 85:
            range = 270
            
        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)
            
# This one is the child class
class ElectricCar(Car):
    
    def __init__(self, make, model, year):
        # First initialize attributes of the parent class.
        super().__init__(make, model, year)
        # Now initialize attributes specific of an electric car.
        self.battery = Battery()

my_tesla = ElectricCar('tesla', 'model s', 2016)
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()

# %%
# Ex 9-6 Ice Cream Stand

# Restaurant class I had created
class Restaurant():
    
    def __init__(self, restaurant_name, cuisine_type):
        self.name = restaurant_name
        self.type = cuisine_type
        self.number_served = 0
        
    def describe_restaurant(self):
        print("\nThe restaurant is named " + self.name.title() + ",")
        print("and it specializes in " + self.type.title() + " cuisine.")
    
    def open_restaurant(self):
        print("\nThe restaurant is now open!")
        
    def set_number_served(self, served):
        self.number_served = served
        
    def increment_number_served(self, daily_served):
        self.number_served += daily_served
    
class IceCreamStand(Restaurant):

    def __init__(self, restaurant_name, cuisine_type):
        super().__init__(restaurant_name, cuisine_type)
        self.flavors = ['chocolate', 'vanilla', 'strawberry', 'rainbow']
        
    def display_flavors(self):
        # Displaying ice cream flavors
        print("\nFlavors we have: ")
        for flavor in self.flavors:
            print(flavor.title())
            
my_restaurant = IceCreamStand('The Ice', 'dessert')
my_restaurant.describe_restaurant()
my_restaurant.display_flavors()

# %%
# Ex. 9-7 Admin

# I will inherit form the Users class I wrote above
class User():
    
    def __init__(self, first_name, last_name, age, role):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age
        self.role = role
        self.login_attempts = 0
        
    def describe_user(self):
        print(self)
    
    def greet_user(self):
        print("Hola " + self.first_name.title())
        
    def increment_login_attempts(self):
        self.login_attempts += 1
    
    def reset_login_attempts(self):
        self.login_attempts = 0

# Create a separate class that will held the priviliges as a separate thing
class Privileges():
    
    def __init__(self):
        self.privileges = ['can add post', 'can delete post', 'can ban user']
    
    def show_privileges(self):
        print("\nThese are the admin privileges: ")
        for privilege in self.privileges:
            print(privilege)

class Admin(User):
    
    def __init__(self, first_name, last_name, age, role):
        super().__init__(first_name, last_name, age, role)
        self.privileges = Privileges()

kaleidos_admin = Admin('Sol', 'Giron', 33, 'admin')
kaleidos_admin.greet_user()
kaleidos_admin.privileges.show_privileges()

# %%
# Ex. 9-9 Battery Upgrade

class Car():
    
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
        
    def get_descriptive_name(self):
        long_name = str(self.year) + " " + self.make + " " + self.model
        return long_name.title()
    
    def read_odometer(self):
        print("This car has " + str(self.odometer_reading) + " miles on it.")
        
    def update_odometer(self, mileage):
        
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else:
            print("The odometer cannot go backwards.")

# New class to hold the battery related attributes
# This will be passed as an attribute to the ElectricCar class later on

class Battery():
    
    def __init__(self, battery_size=70):
        self.battery_size = battery_size
    
    def describe_battery(self):
           print("This car has a " + str(self.battery_size) + "-kWh battery.")
            
    def get_range(self):
        if self.battery_size == 70:
            range = 240
        elif self.battery_size == 85:
            range = 270
            
        message = "This car can go approximately " + str(range)
        message += " miles on a full charge."
        print(message)
    
    def upgrade_battery(self):
        if self.battery_size != 85:
            self.battery_size = 85
            
# This one is the child class
class ElectricCar(Car):
    
    def __init__(self, make, model, year):
        # First initialize attributes of the parent class.
        super().__init__(make, model, year)
        # Now initialize attributes specific of an electric car.
        self.battery = Battery()

my_tesla = ElectricCar('tesla', 'model s', 2016)
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()

# Upgrading my battery.
my_tesla.battery.upgrade_battery()
my_tesla.battery.get_range()

# %%
# Importing a single class

from car import Car

my_new_car = Car('audi', 'a4', 2016)
print(my_new_car.get_descriptive_name())

my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# 2016 Audi A4
# This car has 23 miles on it.

# %%
from car import ElectricCar

my_tesla = ElectricCar('tesla', 'model s', 2016)

print(my_tesla.get_descriptive_name())
my_tesla.battery.describe_battery()
my_tesla.battery.get_range()
# Out:
# 2016 Tesla Model S
# This car has a 70-kWh battery.
# This car can go approximately 240 miles on a full charge.

# %%
import car

my_beetle = car.Car('volkswagen', 'beetle', 2016)
print(my_beetle.get_descriptive_name())

my_tesla = car.ElectricCar('tesla', 'roadster', 2016)
print(my_tesla.get_descriptive_name())
# Out:
# 2016 Volkswagen Beetle
# 2016 Tesla Roadster

# %%
# Ex. 9-10 Imported restaurant: Using the latest Restaurant class, store it in a module.
# Make a separate file that imports Restaurant.  Make a Restaurant instance and call one of 
# Restaurant's methods to show that the import statement is working properly.

from restaurant import Restaurant

marcos_restaurant = Restaurant('Taller Vegano', 'vegana')

# %%
from collections import OrderedDict

favorite_languages = OrderedDict()

favorite_languages['jen'] = 'python'
favorite_languages['sarah'] = 'c'
favorite_languages['edward'] = 'ruby'
favorite_languages['phil'] = 'python'

for name, language in favorite_languages.items():
    print(name.title() + "'s favorite language is " +
         language.title() + ".")
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Ruby.
# Phil's favorite language is Python.

# %%
print(favorite_languages)
# Out:
# OrderedDict([('jen', 'python'), ('sarah', 'c'), ('edward', 'ruby'), ('phil', 'python')])

# %%
# Ex. 9-14 Dice: The module 'random' contains functions that generate random numbers in a variety
# of ways.  The function randint() returns an integer in the range you provide.  The following
# code returns a number between 1 and 6.
# The method prints a random number between 1 and the number of sides the dice has.

from random import randint

class Dice(sides):
    """Una clase que representa un dado."""
    
    def __init__(self, sides):
        """Initialize attributes."""
        self.sides = sides
        if self.sides == 0:
            self.sides = 6
        
    def roll_dice(self):
        """Value of the dice face."""
        dice_value = randint(1,self.sides)
            
        print("The dice has " + self.sides + " faces.")
        print("\nThe dice value is: " + dice_value)
        
        
dado = Dice(6)
dado.roll_dice()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e707ae6d2df2> in <module>
#       6 from random import randint
#       7
# ----> 8 class Dice(sides):
#       9     """Una clase que representa un dado."""
#      10
#
# NameError: name 'sides' is not defined
